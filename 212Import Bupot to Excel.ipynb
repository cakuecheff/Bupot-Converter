# %%
import pdfplumber
import pandas as pd
import os
import re
from IPython.display import display

# Fungsi untuk menggabungkan karakter atau angka yang terpisah satu per satu oleh spasi
def fix_separated_text(text):
    text = re.sub(r'(?<=\b\w) (\w\b)', r'\1', text)  # Menggabungkan angka atau huruf yang seharusnya tergabung
    text = re.sub(r'(?<=\d)(H\.\d)', r' \1', text)  # Menjaga spasi sebelum format khusus
    text = re.sub(r'(?<=\d)(B\.\d)', r' \1', text)
    return text

# Fungsi untuk mengekstrak teks dari satu file PDF dan memisahkannya ke dalam baris berbeda
def extract_text_from_pdf(pdf_path):
    if not os.path.exists(pdf_path):
        print(f"File tidak ditemukan: {pdf_path}")
        return None
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text_lines = []
            for page in pdf.pages:
                text = page.extract_text()
                if text:
                    lines = text.split("\n")
                    cleaned_lines = [fix_separated_text(line) for line in lines]
                    text_lines.extend(cleaned_lines)
        return text_lines
    except Exception as e:
        print(f"Error saat membaca file {pdf_path}: {e}")
        return None

# Folder tempat menyimpan file PDF
folder_path = r"Z:\2. LAPOR TAHUNAN\SEJAHTERA DUNIA AKHIRAT, PT (GRUP)\1 PUSAT\TAHUNAN\2024\Bupot PPh"
pdf_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(".pdf")]

# Dictionary untuk menyimpan data dari setiap file
data_dict = {}

for idx, pdf in enumerate(pdf_files, start=1):
    extracted_text = extract_text_from_pdf(pdf)
    if extracted_text:
        data_dict[f"File_{idx}"] = extracted_text  # Menyimpan data dalam dictionary

# Mencari jumlah baris maksimum agar semua file memiliki panjang yang sama dalam DataFrame
max_rows = max(len(text) for text in data_dict.values())

# Menjadikan dictionary sebagai DataFrame dengan kolom dari setiap file
df = pd.DataFrame({col: text + [""] * (max_rows - len(text)) for col, text in data_dict.items()})

# Menambahkan header angka berurutan
df.columns = [str(i+1) for i in range(len(df.columns))]

# Preview hasil ekstraksi
print("Preview hasil ekstraksi:")
display(df.head(20))  # Menampilkan 20 baris pertama dalam bentuk tabel
# # Inisialisasi list untuk menyimpan data yang telah diproses
output_path = os.path.join(folder_path, "rekap output mentah.xlsx")
df.to_excel(output_path, index=False)

# print(f"Tahap 1 selesai! File disimpan di: {output_path}")
processed_data = []
# Out:
# Preview hasil ekstraksi:
#                                                     1  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000010 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15     1-2024 24-100-01 1.500.000,00 15.00 225.000,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2023/XII...
# 18  Nama Dokumen Invoice Tanggal 13 dd 12 mm 2023 ...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     2  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000332 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15       1-2024 24-100-01 900.000,00 15.00 135.000,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024/I/I...
# 18  Nama Dokumen Invoice Tanggal 12 dd 01 mm 2024 ...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     3  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000394 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15        1-2024 24-100-01 2.003.384,00 15 300.507,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024 / 7...
# 18  Nama Dokumen Biaya Pembayaran Tanggal 19 dd 01...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     4  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000547 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15        1-2024 24-100-01 4.629.372,00 15 694.405,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024 / 7...
# 18  Nama Dokumen Biaya Pembayaran Tanggal 31 dd 01...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     5  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000063 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15              2-2024 24-104-02 162.162,00 23.243,00
# 16       Keterangan Kode Objek Pajak : Jasa Manajemen
# 17              B.7 Dokumen Referensi : Nomor Dokumen
# 18                    Nama Dokumen Tanggal dd mm yyyy
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     6  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000103 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15     2-2024 24-100-01 1.837.838,00 15.00 275.675,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17              B.7 Dokumen Referensi : Nomor Dokumen
# 18                    Nama Dokumen Tanggal dd mm yyyy
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     7  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000622 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15        2-2024 24-100-01 459.460,00 15.00 68.919,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17              B.7 Dokumen Referensi : Nomor Dokumen
# 18                    Nama Dokumen Tanggal dd mm yyyy
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     8  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001176 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15          2-2024 24-104-02 3.000.000,00 2 60.000,00
# 16       Keterangan Kode Objek Pajak : Jasa Manajemen
# 17  B.7 Dokumen Referensi : Nomor Dokumen PIV24020...
# 18  Nama Dokumen Biaya Pembayaran Tanggal 05 dd 02...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                     9  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001177 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15        2-2024 24-104-02 12.010.000,00 2 240.200,00
# 16       Keterangan Kode Objek Pajak : Jasa Manajemen
# 17  B.7 Dokumen Referensi : Nomor Dokumen PIV24020...
# 18  Nama Dokumen Biaya Pembayaran Tanggal 21 dd 02...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                    10  ...  \
# 0                                         areastaples  ...
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN  ...
# 2                                       FORMULIR BPBS  ...
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...  ...
# 4                H.1 NOMOR : 2000000110 H.4 PPh Final  ...
# 5                             KEMENTERIAN KEUANGAN RI  ...
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...  ...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT  ...
# 8                          A.1 NPWP : 800132771643000  ...
# 9                                           A.2 NIK :  ...
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT  ...
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT  ...
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...  ...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...  ...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6  ...
# 15        3-2024 24-100-01 200.000,00 15.00 30.000,00  ...
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...  ...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024/II/...  ...
# 18  Nama Dokumen Invoice Tanggal 26 dd 02 mm 2024 ...  ...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...  ...
#
#                                                    68  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001050 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16             12-2024 24-104-18 150.000,00 23.000,00
# 17  Keterangan Kode Objek Pajak : Jasa Perantara d...
# 18              B.7 Dokumen Referensi : Nomor Dokumen
# 19                    Nama Dokumen Tanggal dd mm yyyy
#
#                                                    69  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001054 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16        12-2024 24-104-18 6.308.400,00 2 126.168,00
# 17  Keterangan Kode Objek Pajak : Jasa Perantara d...
# 18              B.7 Dokumen Referensi : Nomor Dokumen
# 19                    Nama Dokumen Tanggal dd mm yyyy
#
#                                                    70  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001061 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16         12-2024 24-104-18 4.122.000,00 2 82.440,00
# 17  Keterangan Kode Objek Pajak : Jasa Perantara d...
# 18              B.7 Dokumen Referensi : Nomor Dokumen
# 19                    Nama Dokumen Tanggal dd mm yyyy
#
#                                                    71  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000001436 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16      12-2024 24-100-01 700.000,00 15.00 105.000,00
# 17  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 18  B.7 Dokumen Referensi : Nomor Dokumen 2024/XII...
# 19  Nama Dokumen Invoice Tanggal 06 dd 12 mm 2024 ...
#
#                                                    72  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000002608 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16       12-2024 24-100-01 200.000,00 15.00 30.000,00
# 17  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 18  B.7 Dokumen Referensi : Nomor Dokumen 2024/XI/...
# 19  Nama Dokumen Invoice Tanggal 26 dd 11 mm 2024 ...
#
#                                                    73  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000006974 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16        12-2024 24-104-02 5.782.000,00 2 115.640,00
# 17       Keterangan Kode Objek Pajak : Jasa Manajemen
# 18  B.7 Dokumen Referensi : Nomor Dokumen PIV24120...
# 19  Nama Dokumen Biaya Pembayaran Tanggal 05 dd 12...
#
#                                                    74  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000007102 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8       A.1 NPWP : 800132771643000 / 0800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 NITKU : 0800132771643000000000
# 11                 A.4 Nama : SEJAHTERA DUNIA AKHIRAT
# 12        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 13  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 14  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 15                            B.1 B.2 B.3 B.4 B.5 B.6
# 16         12-2024 24-104-02 1.610.000,00 2 32.200,00
# 17       Keterangan Kode Objek Pajak : Jasa Manajemen
# 18  B.7 Dokumen Referensi : Nomor Dokumen PIV24120...
# 19  Nama Dokumen Biaya Pembayaran Tanggal 10 dd 12...
#
#                                                    75  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000205 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15      1-2024 24-100-01 7.316.321,00 15 1.097.448,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024 / 7...
# 18  Nama Dokumen Biaya Pembayaran Tanggal 09 dd 01...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                    76  \
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4                H.1 NOMOR : 2000000276 H.4 PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15     1-2024 24-100-01 3.000.000,00 15.00 450.000,00
# 16  Keterangan Kode Objek Pajak : Hadiah, Pengharg...
# 17  B.7 Dokumen Referensi : Nomor Dokumen 2024/I/I...
# 18  Nama Dokumen Invoice Tanggal 12 dd 01 mm 2024 ...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
#                                                    77
# 0                                         areastaples
# 1                         BUKTI PEMOTONGAN/PEMUNGUTAN
# 2                                       FORMULIR BPBS
# 3   PPh PASAL 4 AYAT (2), PASAL 15, PASAL 22, DAN ...
# 4               H.1 NOMOR : 2000000001 H.4X PPh Final
# 5                             KEMENTERIAN KEUANGAN RI
# 6   DIREKTORAT JENDERAL PAJAK H.2 Pembetulan Ke- 0...
# 7     A. IDENTITAS WAJIB PAJAK YANG DIPOTONG/DIPUNGUT
# 8                          A.1 NPWP : 800132771643000
# 9                                           A.2 NIK :
# 10                 A.3 Nama : SEJAHTERA DUNIA AKHIRAT
# 11        B. PAJAK PENGHASILAN YANG DIPOTONG/DIPUNGUT
# 12  Masa Pajak Dikenakan Tarif Lebih PPh yang Dipo...
# 13  (mm-yyyy) Kode Objek Pajak Dasar Pengenaan Paj...
# 14                            B.1 B.2 B.3 B.4 B.5 B.6
# 15  1-2024 28-403-02 100.000.000,00 10.00 10.000.0...
# 16  Keterangan Kode Objek Pajak : Persewaan Tanah ...
# 17            B.7 Dokumen Referensi : Nomor Dokumen -
# 18  Nama Dokumen Akta Perikatan Tanggal 11 dd 01 m...
# 19  B.8 Dokumen Referensi untuk Faktur Pajak, apab...
#
# [20 rows x 77 columns]

# %%
# Lanjut ke proses kedua
file_path = output_path
sheet_name = 'Sheet1'
df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
processed_data = []
# Fungsi untuk mendapatkan nilai dari baris tertentu, jika tidak sesuai format cek baris berikutnya
def get_valid_value(df, row_list, col, keyword="", remove_spaces=True):
    """ Cek beberapa baris hingga menemukan format yang benar """
    for row in row_list:
        if row < len(df) and pd.notna(df.iloc[row, col]):
            value = str(df.iloc[row, col]).replace(keyword, "").strip()
            return value.replace(" ", "") if remove_spaces else value
    return "-"

# Fungsi untuk mengambil tanggal dengan format yang benar
def get_valid_date(df, row_list, col):
    """ Cek beberapa baris hingga menemukan format tanggal yang benar """
    for row in row_list:
        if row < len(df) and pd.notna(df.iloc[row, col]):
            tanggal_parts = str(df.iloc[row, col]).split()
            if len(tanggal_parts) >= 8:
                return f"{tanggal_parts[3]}/{tanggal_parts[5]}/{tanggal_parts[7]}"
    return "00/00/0000"
# Inisialisasi list untuk menyimpan data yang telah diproses
for col in df.columns:
    # Ambil data dari baris yang sesuai
    npwp = get_valid_value(df, [28, 29], col, "C.1 NPWP :")  # Cek di baris 28, jika kosong cek di baris 29
    npwp = npwp[4]
     # Ambil data dari baris yang sesuai setelah pembersihan
    npwp = df.iloc[28, col].replace("C.1 NPWP : ", "").replace(" ", "")
        
    # Ambil nama pemotong dengan regex untuk menghapus "C.X Nama Wajib Pajak : " (X bisa angka berapa pun)
    nama_pemotong = re.sub(r'C\.\d+ Nama Wajib Pajak : ', '', df.iloc[29, col])

    # Ambil jenis PPH, jika baris 16 salah cek baris 17
    jenis_pph_raw = get_valid_value(df, [16, 17], col, remove_spaces=False).split()
    jenis_pph_clean = "".join(filter(str.isdigit, jenis_pph_raw[1].split('-')[0])) if len(jenis_pph_raw) > 1 else "00"
    jenis_pph = "22" if jenis_pph_clean.isdigit() and int(jenis_pph_clean) <= 17 else "23"

    # Ambil objek potput dan pph potput
    objek_potput = jenis_pph_raw[2].replace(".", "").replace(",00", "") if len(jenis_pph_raw) > 2 else "0"
    pph_potput = jenis_pph_raw[4].replace(".", "").replace(",00", "") if len(jenis_pph_raw) > 4 else "0"
    # pph_potput = jenis_pph_raw[3].replace(".", "").replace(",00", "") if len(jenis_pph_raw) > 4 else jenis_pph_raw[4]
    # no_bukti = df.iloc[5, col].split()[5]

    # Ambil nomor bukti, jika tidak ditemukan cek baris berikutnya
    no_bukti = str(df.iloc[18, 5]).replace("H.1 NOMOR : ", "").replace(" H.4 PPh Final", "") if pd.notna(df.iloc[18, 5]) else "-"
    no_bukti = get_valid_value(df, [5, 18], col, remove_spaces=False).split()
    no_bukti = no_bukti[3].replace("H.1 NOMOR : ", "").replace(" H.4 PPh Final", "") if len(no_bukti) > 6 else "-"
    
    # Ambil data tanggal dari baris ke-31
    tanggal_bukti_raw = df.iloc[30, col].split()  # Pisahkan teks berdasarkan spasi
    tahun = tanggal_bukti_raw[7]  # Ambil tahun (indeks 5)
    bulan = tanggal_bukti_raw[5]  # Ambil bulan (indeks 3)
    hari = tanggal_bukti_raw[3]   # Ambil hari (indeks 1)

    # Format tanggal menjadi "hari/bulan/tahun"
    tanggal_bukti = f"{hari}/{bulan}/{tahun}"

    alamat_pemotong = "-"
    ntpn = "-"

    # Tambahkan data yang telah diproses ke list
    processed_data.append([
        len(processed_data) + 1,  # NO
        nama_pemotong,            # NAMA PEMOTONG/ PEMUNGUT
        npwp,                     # NPWP
        jenis_pph,                # JENIS PPH
        "1",                      # JENIS PENGHASILAN
        objek_potput,             # OBJEK POTPUT (Rupiah)
        pph_potput,               # PPH POTPUT
        no_bukti,                 # NO BUKTI
        tanggal_bukti,            # TANGGAL BUKTI
        alamat_pemotong,          # ALAMAT PEMOTONG/ PEMUNGUT
        ntpn                      # NTPN
    ])

# Buat DataFrame dari data yang telah diproses
output_df = pd.DataFrame(processed_data, columns=[
    "NO", "NAMA PEMOTONG/ PEMUNGUT", "NPWP", "JENIS PPH", "JENIS PENGHASILAN", 
    "OBJEK POTPUT (Rupiah)", "PPH POTPUT", "NO BUKTI", "TANGGAL BUKTI", 
    "ALAMAT PEMOTONG/ PEMUNGUT", "NTPN"
])

# Preview hasil akhir
print("Preview hasil akhir:")
display(output_df.head(20))  # Menampilkan 20 baris pertama dalam bentuk tabel
# Out:
# Preview hasil akhir:
#     NO             NAMA PEMOTONG/ PEMUNGUT             NPWP JENIS PPH  \
# 0    1  WORLD INNOVATIVE TELECOMMUNICATION  740330766606001        23
# 1    2  WORLD INNOVATIVE TELECOMMUNICATION  740330766606001        23
# 2    3                    FINNET INDONESIA  024793911062000        23
# 3    4                    FINNET INDONESIA  024793911062000        23
# 4    5             HARAPAN CELLULAR MAKMUR  707513677616000        23
# 5    6  WORLD INNOVATIVE TELECOMMUNICATION  740330766652001        23
# 6    7  WORLD INNOVATIVE TELECOMMUNICATION  740330766606001        23
# 7    8              MAJU EXPRESS INDONESIA  025761057415000        23
# 8    9              MAJU EXPRESS INDONESIA  025761057415000        23
# 9   10  WORLD INNOVATIVE TELECOMMUNICATION  740330766652001        23
# 10  11        UWINFLY INDONESIA INDUSTRIES  857558860503000        23
# 11  12  WORLD INNOVATIVE TELECOMMUNICATION  740330766627001        23
# 12  13                 OASE TEKNOLOGI ASIA  836907592606001        23
# 13  14  WORLD INNOVATIVE TELECOMMUNICATION  740330766652001        23
# 14  15         HARAPAN TEKNOLOGI INDONESIA  412504656613000        23
# 15  16  WORLD INNOVATIVE TELECOMMUNICATION  740330766606001        23
# 16  17                 OASE TEKNOLOGI ASIA  836907592606001        23
# 17  18                    BLUE OCEAN HEART  826777286617001        23
# 18  19                    BLUE OCEAN HEART  826777286901001        23
# 19  20          COSMO TECHNOLOGY INDONESIA  625253927609000        23
#
#    JENIS PENGHASILAN OBJEK POTPUT (Rupiah) PPH POTPUT    NO BUKTI  \
# 0                  1               1500000     225000  2000000010
# 1                  1                900000     135000  2000000332
# 2                  1               2003384     300507  2000000394
# 3                  1               4629372     694405  2000000547
# 4                  1                162162          0  2000000063
# 5                  1               1837838     275675  2000000103
# 6                  1                459460      68919  2000000622
# 7                  1               3000000      60000  2000001176
# 8                  1              12010000     240200  2000001177
# 9                  1                200000      30000  2000000110
# 10                 1               5584685      25131  2000000778
# 11                 1                700000     105000  2000000031
# 12                 1                438823      65823  2000000052
# 13                 1               1837837     275675  2000000213
# 14                 1              72072072    1441441  2000000029
# 15                 1               2000000     300000  2000001410
# 16                 1               2200000      44000  2000000065
# 17                 1                720721      14414  2000000098
# 18                 1                180180          0  2000000246
# 19                 1               2706981      54139  2000000481
#
#    TANGGAL BUKTI ALAMAT PEMOTONG/ PEMUNGUT NTPN
# 0     03/01/2024                         -    -
# 1     29/01/2024                         -    -
# 2     19/01/2024                         -    -
# 3     31/01/2024                         -    -
# 4     10/02/2024                         -    -
# 5     29/02/2024                         -    -
# 6     29/02/2024                         -    -
# 7     05/02/2024                         -    -
# 8     21/02/2024                         -    -
# 9     05/03/2024                         -    -
# 10    15/03/2024                         -    -
# 11    22/01/2024                         -    -
# 12    25/04/2024                         -    -
# 13    25/04/2024                         -    -
# 14    04/06/2024                         -    -
# 15    31/05/2024                         -    -
# 16    05/06/2024                         -    -
# 17    03/06/2024                         -    -
# 18    06/06/2024                         -    -
# 19    30/06/2024                         -    -

# %%
output_file_path = 'output_data.txt'
output_df.to_csv(output_file_path, sep='\t', index=False)  # Menyimpan dalam format txt dengan pemisah tab

print(f"Data telah disimpan ke {output_file_path}")
# Out:
# Data telah disimpan ke output_data.txt

# %%
output_file_path = "output_data.csv"
output_df.to_csv(output_file_path, sep=';', index=False)

print(f"Data telah disimpan ke {output_file_path}")
# Out:
# Data telah disimpan ke output_data.csv

# %%
# Simpan hasil ke file Excel
output_file_path = "mport bupot.xlsx"
output_df.to_excel(output_file_path, index=False)  # Menyimpan dalam format Excel

print(f"Data telah disimpan ke {output_file_path}")
# Out:
# Data telah disimpan ke mport bupot.xlsx
